# %%
from hydrocomp.series import flow, rainfall
import plotly as py

# %%
# Estações de Vazão
stations_flow = ['76100000', '76310000', '76380000', '76440000', '76460000', '76750000', '76800000']

# Estações de Precipitação
stations_rainfall = ['835142', '835140', '835050', '835043', '835026', '835025', '835015', '835014', '835002', '835000']

# %%
flow = flow.Flow(path_file=stations_flow, source='ANA', consistence=1)

# %%
flow.data
# Out:
#            76100000  76310000  76380000  76440000  76460000  76750000  \
# Date
# 1940-04-01      NaN       NaN      45.6       NaN       NaN       NaN
# 1940-04-02      NaN       NaN      24.3       NaN       NaN       NaN
# 1940-04-03      NaN       NaN      15.6       NaN       NaN       NaN
# 1940-04-04      NaN       NaN      14.1       NaN       NaN       NaN
# 1940-04-05      NaN       NaN      11.2       NaN       NaN       NaN
# ...             ...       ...       ...       ...       ...       ...
# 2019-08-27  23.7623       NaN       NaN   20.8881   10.2076   30.3390
# 2019-08-28  23.1184       NaN       NaN   17.5862    9.3914   36.8642
# 2019-08-29  22.4825       NaN       NaN   21.9260    8.6089   35.2848
# 2019-08-30  21.8545       NaN       NaN   28.6860    9.7953   32.0183
# 2019-08-31  25.7413       NaN       NaN   29.1373   30.9858   29.6039
#
#             76800000
# Date
# 1940-04-01       NaN
# 1940-04-02       NaN
# 1940-04-03       NaN
# 1940-04-04       NaN
# ...

# %%
fig, data = flow.gantt(name='Gantt')
# Out:
# /home/clebsonpy/Documents/Projetos/HydroComp/exemples/venv/lib/python3.6/site-packages/plotly/figure_factory/_gantt.py:49: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated

# %%
py.offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="31172e6a-8cb7-4a82-b532-b83006379da2" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("31172e6a-8cb7-4a82-b532-b83006379da2")) {
#                     Plotly.newPlot(
#                         '31172e6a-8cb7-4a82-b532-b83006379da2',
# ...

# %%
fig_h, data = flow.plot_hydrogram('Hidro')

# %%
fig_h.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-1c2381a3e659> in <module>
# ----> 1 fig_h.show()
#
# AttributeError: 'dict' object has no attribute 'show'
